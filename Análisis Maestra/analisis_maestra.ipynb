# %%
import pandas as pd

# Ruta al archivo
file_path = r"C:\Users\rodri\OneDrive\Escritorio\Roxana Files\base_maestra\base_maestra.xlsx"

# Cargar la base maestra actualizada
base_maestra = pd.read_excel(file_path)

base_maestra
# Out:
#         ID      FOLIO                              NOMBRE       SEXO  \
# 0        1   72160230     ABELINO ENRIQUE JIMENEZ GAJARDO  MASCULINO
# 1        2   21150571        ABRAHAM BENJAMIN NOVOA LAGOS  MASCULINO
# 2        3   72170568         ACCEL NICOLAS ABARCA PROUZA  MASCULINO
# 3        4   72170089             ADELAIDA BARROS CAJDLER   FEMENINO
# 4        5   21160652       ADOLFO FERNANDO AGURTO DETZEL  MASCULINO
# ...    ...        ...                                 ...        ...
# 3140  3141  621472335  RODRIGO HERNAN GUTIERREZ AQUEVEQUE  MASCULINO
# 3141  3142   72150131          SANDRA ANDREA ROJAS AZOCAR   FEMENINO
# 3142  3143   21160818   SEBASTIAN ANDRES RIQUELME BARRIOS  MASCULINO
# 3143  3144   72160304               SEBASTIAN TAPIA LEWIN  MASCULINO
# 3144  3145   21140057     SERGIO ANTONIO CONTRERAS HANTKE  MASCULINO
#
#               AREA_OCDE  Fecha inicio_beca    TIPO_BECA  \
# 0                  STEM               2015  BECAS CHILE
# ...

# %%
base_maestra.shape
# Out:
# (3145, 43)

# %%
base_maestra.dtypes
# Out:
# ID                                      int64
# FOLIO                                   int64
# NOMBRE                                 object
# SEXO                                   object
# AREA_OCDE                              object
# Fecha inicio_beca                       int64
# TIPO_BECA                              object
# UNIVERSIDAD_PROGRAMA                   object
# PROGRAMA                               object
# PAIS                                   object
# Tipo de establecimiento secundario     object
# Pregrado                               object
# Colegio Publico                       float64
# Colegio Particular Pagado             float64
# Extranjero                            float64
# Secundaria en region Chile            float64
# Nombre                                 object
# Comuna                                 object
# Región                                 object
# GSE                                    object
# ...

# %%
distinct_rbd = base_maestra['RBD'].unique()
total_distinct_rbd = len(distinct_rbd)
print(distinct_rbd)
print(f"Total distinct RBD values: {total_distinct_rbd}")
# Out:
# [8748 4824 11962 8906 5024 2579 9406 '8492' nan 60 8928 25055 8757 7700
#  8485 8854 10658 4829 2309 25481 8044 5810 1586 8488 8464 8589 6832 8892
#  3202 5218 14487 25770 69 8927 3711 1464 280 8636 7329 9340 24307 9147
#  8819 24826 9250 25065 26411 8902 8917 4555 1515 8490 2935 17833 5435 1757
#  5808 1638 6754 2110 7299 1436 10162 337 7129 9185 8491 4686 14334 2040
#  8654 10526 4698 11776 3530 2973 8863 8909 24410 12062 9071 8956 4662 9276
#  15707 'Estudios en el extranjero' 1194 2200 342 15524 9519 1977 4553 9237
#  2049 5570 5666 9058 8930 9472 9693 8991 9356 17855 10618 1363 25722 8487
#  8969 9230 7435 25439 429 8995 583 6836 20235 9051 1604 3718 8868 1587
#  1631 8923 1911 9767 8492 1582 132 8870 12087 25843 4163 11968 8925 6844
#  4702 8888 10723 8002 3539 9073 5344 12935 8627 4557 25402 7639 4711 18007
#  9271 287 1755 5215 14280 9239 9221 4687 8650 8680 14348 7200 2444 2355
#  10635 24884 8603 6753 2260 8750 5816 24207 9267 9909 9278 8754 3713 22236
# ...
