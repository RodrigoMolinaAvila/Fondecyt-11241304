# %% [markdown]
# Librerías:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Path:

# %%
file_path = r"./maestra.xlsx"
df = pd.read_excel(file_path, sheet_name="BaseMaestra")
df.head(10)
# Out:
#       FOLIO                           NOMBRE Primer_Nombre Segundo_Nombre  \
# 0  72160230  ABELINO ENRIQUE JIMENEZ GAJARDO       ABELINO        ENRIQUE
# 1  21150571     ABRAHAM BENJAMIN NOVOA LAGOS       ABRAHAM       BENJAMIN
# 2  72170568      ACCEL NICOLAS ABARCA PROUZA         ACCEL        NICOLAS
# 3  72170089          ADELAIDA BARROS CAJDLER      ADELAIDA         BARROS
# 4  72170561       ADOLFO ANTONIO ROCCO ROCCO        ADOLFO        ANTONIO
# 5  21151459        ADOLFO EDGARDO ISLA MUÑOZ        ADOLFO        EDGARDO
# 6  21160652    ADOLFO FERNANDO AGURTO DETZEL        ADOLFO       FERNANDO
# 7  72170429       ADOLFO IGNACIO BARROS ROMO        ADOLFO        IGNACIO
# 8  21150969  ADRIAN EMMANUEL ROJAS SEPULVEDA        ADRIAN       EMMANUEL
# 9  21151411           ADRIAN GARRIDO BIGOTES        ADRIAN        GARRIDO
#
#   Apellido_Paterno Apellido_Materno SEXO_COMPLETO ESTADO BECA  \
# 0          JIMENEZ          GAJARDO     MASCULINO  NO VIGENTE
# ...

# %% [markdown]
# Nulos:

# %%
df.isnull().sum()
# Out:
# FOLIO                                               0
# NOMBRE                                              0
# Primer_Nombre                                       0
# Segundo_Nombre                                      0
# Apellido_Paterno                                   36
# Apellido_Materno                                  520
# SEXO_COMPLETO                                       0
# ESTADO BECA                                         0
# Ano de inicio beca                                  0
# TIPO_BECA                                           0
# AREA_OCDE                                           0
# UNIVERSIDAD_PROGRAMA                                0
# PROGRAMA                                            4
# Pais                                                0
# Estudios en el extranjero                           0
# Acredita grado                                      0
# Retornado Becas Chile                               0
# ...

# %%
df.shape
# Out:
# (3166, 55)

# %%
df.dtypes
# Out:
# FOLIO                                              int64
# NOMBRE                                            object
# Primer_Nombre                                     object
# Segundo_Nombre                                    object
# Apellido_Paterno                                  object
# Apellido_Materno                                  object
# SEXO_COMPLETO                                     object
# ESTADO BECA                                       object
# Ano de inicio beca                                 int64
# TIPO_BECA                                         object
# AREA_OCDE                                         object
# UNIVERSIDAD_PROGRAMA                              object
# PROGRAMA                                          object
# Pais                                              object
# Estudios en el extranjero                          int64
# Acredita grado                                    object
# ...

# %%
df.head(5)
# Out:
#       FOLIO                           NOMBRE Primer_Nombre Segundo_Nombre  \
# 0  72160230  ABELINO ENRIQUE JIMENEZ GAJARDO       ABELINO        ENRIQUE
# 1  21150571     ABRAHAM BENJAMIN NOVOA LAGOS       ABRAHAM       BENJAMIN
# 2  72170568      ACCEL NICOLAS ABARCA PROUZA         ACCEL        NICOLAS
# 3  72170089          ADELAIDA BARROS CAJDLER      ADELAIDA         BARROS
# 4  72170561       ADOLFO ANTONIO ROCCO ROCCO        ADOLFO        ANTONIO
#
#   Apellido_Paterno Apellido_Materno SEXO_COMPLETO ESTADO BECA  \
# 0          JIMENEZ          GAJARDO     MASCULINO  NO VIGENTE
# 1            NOVOA            LAGOS     MASCULINO  NO VIGENTE
# 2           ABARCA           PROUZA     MASCULINO  NO VIGENTE
# 3           BARROS              NaN      FEMENINO  NO VIGENTE
# 4            ROCCO            ROCCO     MASCULINO  NO VIGENTE
#
#    Ano de inicio beca    TIPO_BECA  ... DURACION_MESES TIPO_BENEFICIARIO  \
# ...
